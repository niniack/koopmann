# %%
from copy import deepcopy


import panel as pn
import plotly.express as px
import torch
from processor import Processor
from safetensors import safe_open
from scipy.spatial import procrustes
from sklearn.decomposition import PCA
from torch import nn
from torch.utils.data import DataLoader, Subset
from torcheval.metrics import MulticlassAccuracy

from analysis.common import load_autoencoder, load_model
from koopmann import aesthetics

# from koopmann import aesthetics
from koopmann.data import (
    DatasetConfig,
    get_dataset_class,
)
from scripts.train_ae.shape_metrics import prepare_acts, undo_preprocessing_acts

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dataset_name = "lotusroot"
model_name = f"resmlp_{dataset_name}"
file_dir = "/Users/nsa325/Documents/koopmann_model_saves"
data_root = "/Users/nsa325/datasets/"

# %%
if dataset_name == "lotusroot":
    dim = 20
    scale_idx = 1
    k_steps = 100
    flavor = "exponential"
elif dataset_name == "mnist":
    dim = 800
    scale_idx = 1
    k_steps = 10
    flavor = "exponential"
elif dataset_name == "cifar10":
    dim = 1_000
    scale_idx = 1
    k_steps = 100
    flavor = "exponential"
else:
    raise NotImplementedError()

ae_name = f"dim_{dim}_k_{k_steps}_loc_{scale_idx}_{flavor}_autoencoder_{dataset_name}_model"
device = "cpu"

# %%
model, model_metadata = load_model(file_dir, model_name)
model.eval().hook_model().to(device)
print("Model: ", model_metadata)

autoencoder, ae_metadata = load_autoencoder(file_dir, ae_name)
autoencoder.eval().to(device)
new_dim = ae_metadata["in_features"]
preprocess = ae_metadata["preprocess"]
K_matrix = autoencoder.koopman_weights.T
print("Autoencoder: ", ae_metadata)
# Out:
# Model:  {'batchnorm': True, 'bias': True, 'created_at': '2025-04-30T10:33:25.774294', 'dataset': 'LotusRootDataset', 'hidden_config': [10, 10, 10, 10], 'in_features': 2, 'model_class': 'ResMLP', 'nonlinearity': 'relu', 'out_features': 2, 'stochastic_depth_mode': 'batch', 'stochastic_depth_prob': 0.0}
# Autoencoder:  {'batchnorm': False, 'bias': True, 'created_at': '2025-05-01T13:48:07.748422', 'hidden_config': [30], 'in_features': 10, 'k_steps': 100, 'latent_features': 20, 'model_class': 'ExponentialKoopmanAutencoder', 'nonlinearity': 'leaky_relu', 'preprocess': True}

# %%
dataset_config = DatasetConfig(
    dataset_name=model_metadata["dataset"],
    num_samples=3_000,
    split="train",
    seed=42,
)
DatasetClass = get_dataset_class(name=dataset_config.dataset_name)
dataset = DatasetClass(config=dataset_config, root=data_root)

subset_size = 3_000
if subset_size:
    subset_indices = list(range(0, subset_size))
    subset = Subset(dataset, subset_indices)

batch_size = 3_000
batch_size = min(subset_size, batch_size) if subset_size else batch_size
dataloader = DataLoader(subset if subset_size else dataset, batch_size=batch_size, shuffle=False)

# %%
def compute_reference_bases(data):
    # Compute PCA reference basis
    pca = PCA(n_components=3)
    ref = pca.fit_transform(data)
    return ref


def align_using_procrustes(reference_points, new_points):
    _, new_points_aligned, _ = procrustes(reference_points, new_points)
    return new_points_aligned


def process_pca_and_align(data, reference):
    """Applies PCA, aligns using Procrustes, and returns aligned data."""
    pca = PCA(n_components=3)
    pca_result = pca.fit_transform(data)
    pca_result = align_using_procrustes(reference, pca_result)
    return pca_result


def create_3d_scatter_plot(data, labels, axis_range):
    x, y, z = data[:, 0], data[:, 1], data[:, 2]

    str_labels = [str(label) for label in labels]
    color = str_labels

    # pca_scalar_field = np.linalg.norm(ref_a, axis=1)
    # color = pca_scalar_field
    # color_continuous_scale="Viridis")
    fig = px.scatter_3d(x=x, y=y, z=z, color=color)

    fig.update_traces(marker=dict(size=1))
    fig.update_layout(
        scene=dict(
            xaxis=dict(range=axis_range),
            yaxis=dict(range=axis_range),
            zaxis=dict(range=axis_range),
            aspectmode="cube",
            aspectratio=dict(x=1, y=1, z=1),
        ),
        showlegend=False,
    )
    return fig

# %%
preproc_dict = {}
with safe_open(
    f"{file_dir}/{ae_name}_preprocessing.safetensors", framework="pt", device="cpu"
) as f:
    for k in f.keys():
        preproc_dict[k] = f.get_tensor(k)

# %%
# Enable Panel for Jupyter
pn.extension()

# Activations from original model
with torch.no_grad():
    orig_act_dict, proc_act_dict, _ = prepare_acts(
        data_train_loader=dataloader,
        model=model,
        device=device,
        svd_dim=ae_metadata["in_features"],
        whiten_alpha=preproc_dict["wh_alpha_0"],
        preprocess=preprocess,
        preprocess_dict=preproc_dict,
        only_first_last=True,
    )
    proc_act_dict = orig_act_dict if not preprocess else proc_act_dict

align_idx = 0
ref_act = compute_reference_bases(proc_act_dict[align_idx])
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='f89deb97-dfb1-4dcd-9896-b18b05f99e8a'>
#   <div id="d3f9ab41-22a9-4b74-9db3-538d89ebb749" data-root-id="f89deb97-dfb1-4dcd-9896-b18b05f99e8a" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"7492fbf9-e150-44f8-be44-73731d23c2ac":{"version":"3.7.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"f89deb97-dfb1-4dcd-9896-b18b05f99e8a"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"17d165f1-2fee-442d-91e6-e9fa2e051ee6","attributes":{"plot_id":"f89deb97-dfb1-4dcd-9896-b18b05f99e8a","comm_id":"36df5c9fe06847db85ac18dd1c910bc5","client_comm_id":"8af463bba7d045c4b6a45594983346d5"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1" ...
#   var render_items = [{"docid":"7492fbf9-e150-44f8-be44-73731d23c2ac","roots":{"f89deb97-dfb1-4dcd-9896-b18b05f99e8a":"d3f9ab41-22a9-4b74-9db3-538d89ebb749"},"root_ids":["f89deb97-dfb1-4dcd-9896-b18b05f99e8a"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
init_idx = list(orig_act_dict.keys())[0]
final_idx = list(orig_act_dict.keys())[-1]

with torch.no_grad():
    x_proj = proc_act_dict[init_idx]
    ae_result = autoencoder(x_proj, intermediate=True)

print(ae_result.predictions.shape)
# Out:
# torch.Size([101, 3000, 10])

# %%
# # Slider
# layer_select = pn.widgets.IntSlider(
#     name="Layer Selector", start=0, end=list(proc_act_dict.keys())[-1], step=1, value=0
# )


# # Plotter
# def update_plots(data_a, data_b, ref_a, ref_b, labels):
#     """Updates PCA and RP plots with the given data and references."""
#     # Default axis range
#     pca_axis_range = [-0.05, 0.05]

#     # First plot: PCA
#     aligned_pca_result = process_pca_and_align(data_a, ref_a)
#     first_fig = create_3d_scatter_plot(aligned_pca_result, labels, pca_axis_range)

#     # Second plot: PCA
#     aligned_pca_result = process_pca_and_align(data_b, ref_b)
#     second_fig = create_3d_scatter_plot(aligned_pca_result, labels, pca_axis_range)

#     return first_fig, second_fig


# # View fn
# @pn.depends(layer_select.param.value)
# def view(layer_index):
#     figs = update_plots(
#         proc_act_dict[layer_index],
#         proc_act_dict[layer_index],
#         ref_act,
#         ref_act,
#         dataset.labels if not subset_size else dataset.labels[:subset_size],
#     )

#     panes = [pn.pane.Plotly(fig) for fig in figs]

#     return pn.Row(*panes, align="center")


# # Layout
# layout = pn.Column(
#     pn.Row(layer_select, align="center"),
#     view,
#     align="center",
#     sizing_mode="stretch_width",
# )

# # Display
# layout.show()

# %%
# Slider
layer_select = pn.widgets.IntSlider(
    name="Layer Selector", start=0, end=ae_result.predictions.shape[0], step=1, value=0
)


# Plotter
def update_plots(data_a, data_b, ref_a, ref_b, labels):
    """Updates PCA and RP plots with the given data and references."""
    # Default axis range
    pca_axis_range = [-0.05, 0.05]

    # First plot: PCA
    aligned_pca_result = process_pca_and_align(data_a, ref_a)
    first_fig = create_3d_scatter_plot(aligned_pca_result, labels, pca_axis_range)

    # Second plot: PCA
    aligned_pca_result = process_pca_and_align(data_b, ref_b)
    second_fig = create_3d_scatter_plot(aligned_pca_result, labels, pca_axis_range)

    return first_fig, second_fig


# View fn
@pn.depends(layer_select.param.value)
def view(layer_index):
    figs = update_plots(
        ae_result.predictions[layer_index],
        ae_result.predictions[layer_index],
        ref_act,
        ref_act,
        dataset.labels if not subset_size else dataset.labels[:subset_size],
    )

    panes = [pn.pane.Plotly(fig) for fig in figs]

    return pn.Row(*panes, align="center")


# Layout
layout = pn.Column(
    pn.Row(layer_select, align="center"),
    view,
    align="center",
    sizing_mode="stretch_width",
)

# Display
layout.show()
# Out:
# Launching server at http://localhost:65182
# 2025-05-03 08:07:10 - WARNING - Dropping a patch because it contains a previously known reference (id='eb0bac2b-cda2-4ad6-a141-f182c58419ed'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:10 - WARNING - Dropping a patch because it contains a previously known reference (id='e75923b1-8dd6-4497-b26a-c10a29d53623'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:11 - WARNING - Dropping a patch because it contains a previously known reference (id='9ea436f6-4e28-4de7-8b5b-57cc0801d18a'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:11 - WARNING - Dropping a patch because it contains a previously known reference (id='c69e2773-10af-4b4f-88f9-549cf60a021c'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:11 - WARNING - Dropping a patch because it contains a previously known reference (id='959a590b-4591-407e-b78e-c48bcab775d1'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:11 - WARNING - Dropping a patch because it contains a previously known reference (id='931b60dc-a750-4acc-a3ee-b6b615b1fd0d'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:11 - WARNING - Dropping a patch because it contains a previously known reference (id='0dd2e685-e379-42dc-a164-17e033615b7c'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:11 - WARNING - Dropping a patch because it contains a previously known reference (id='02c80020-0b49-4ada-878d-187f60a1fdbd'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:12 - WARNING - Dropping a patch because it contains a previously known reference (id='95047051-23ff-4c45-995e-9f0cabf9c6d8'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:12 - WARNING - Dropping a patch because it contains a previously known reference (id='e65d788b-3ffb-4101-b342-4e7fd4d8a759'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:12 - WARNING - Dropping a patch because it contains a previously known reference (id='ae9e7521-ecea-4305-916f-cde201b9a746'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:12 - WARNING - Dropping a patch because it contains a previously known reference (id='9eab952a-dcdc-4f81-8a6e-f54c89391c54'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:12 - WARNING - Dropping a patch because it contains a previously known reference (id='72271449-8632-4348-a416-6ac2bc2caba0'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:12 - WARNING - Dropping a patch because it contains a previously known reference (id='af5ab978-c2df-4580-8b2a-f24865a46d9d'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:12 - WARNING - Dropping a patch because it contains a previously known reference (id='d91d5ee5-0678-4a99-bd07-3b554ed02a19'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:12 - WARNING - Dropping a patch because it contains a previously known reference (id='65e435b5-c4b8-4ac7-a718-c79bf925e625'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:12 - WARNING - Dropping a patch because it contains a previously known reference (id='162df423-e4c9-4cff-a05a-f2578a358a67'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:12 - WARNING - Dropping a patch because it contains a previously known reference (id='692f27fb-5e1e-4913-9a62-f124fe8b4f57'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:13 - WARNING - Dropping a patch because it contains a previously known reference (id='7ddc3ef8-3d09-4e5a-b8e5-a8e54a296e70'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:13 - WARNING - Dropping a patch because it contains a previously known reference (id='ad45a391-f045-4990-9e44-730f78990402'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:13 - WARNING - Dropping a patch because it contains a previously known reference (id='ae61055b-f1d2-46ec-9834-4c351ec0254c'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:13 - WARNING - Dropping a patch because it contains a previously known reference (id='1e9b68ab-334f-4f83-9d36-ce2ab07e54c6'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:13 - WARNING - Dropping a patch because it contains a previously known reference (id='7fa5a0bf-d617-4b16-9755-24c3f0b6767e'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:13 - WARNING - Dropping a patch because it contains a previously known reference (id='038e94d0-7f21-4ee3-8cec-956627670e6f'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:13 - WARNING - Dropping a patch because it contains a previously known reference (id='8baee815-2268-466c-a8e6-c79d27e28d6d'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:13 - WARNING - Dropping a patch because it contains a previously known reference (id='3a65c98e-19a1-4054-8890-2705001f2ca5'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:14 - WARNING - Dropping a patch because it contains a previously known reference (id='d64bfe2f-8b12-4fa6-9d9f-214b011f90a5'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:14 - WARNING - Dropping a patch because it contains a previously known reference (id
3'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:23 - WARNING - Dropping a patch because it contains a previously known reference (id='0619aed0-10f7-4ac5-aae2-1292acc897d3'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:24 - WARNING - Dropping a patch because it contains a previously known reference (id='690afe6b-d5cd-470e-96fa-a67ee30d3339'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:24 - WARNING - Dropping a patch because it contains a previously known reference (id='be47ef3d-aed0-4c5b-b49d-8bf71b965ca2'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:24 - WARNING - Dropping a patch because it contains a previously known reference (id='f610c437-1b58-4e90-b32e-215e02717f1a'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:24 - WARNING - Dropping a patch because it contains a previously known reference (id='28bebbaa-f66c-40c3-8188-73fd7fc26a12'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:24 - WARNING - Dropping a patch because it contains a previously known reference (id='832b36f9-139b-47b6-a01c-83be0915f385'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:24 - WARNING - Dropping a patch because it contains a previously known reference (id='4cff499a-df90-4ba5-acf1-a8e5951127ef'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:24 - WARNING - Dropping a patch because it contains a previously known reference (id='b0510e40-031a-4d67-b340-b720e80dd767'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:24 - WARNING - Dropping a patch because it contains a previously known reference (id='b296d183-a3e9-43e4-b833-001720f4bc2b'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:25 - WARNING - Dropping a patch because it contains a previously known reference (id='5f24ce8c-8d3a-4810-b28d-1f7462da9481'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:25 - WARNING - Dropping a patch because it contains a previously known reference (id='0b8d4da3-71d5-476e-8587-1a3f1984df88'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:25 - WARNING - Dropping a patch because it contains a previously known reference (id='5e173f35-3739-448b-a1f3-d5311adb037c'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:25 - WARNING - Dropping a patch because it contains a previously known reference (id='4ab9f3f6-8263-4748-93e0-37679c8d8add'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:25 - WARNING - Dropping a patch because it contains a previously known reference (id='6511aa6c-4ce6-4a3a-9f39-b3bb1df6749f'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:25 - WARNING - Dropping a patch because it contains a previously known reference (id='55f591a2-f77a-4b99-8b5c-8f828f34f9a8'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:25 - WARNING - Dropping a patch because it contains a previously known reference (id='3829ba93-4e52-4129-903a-5b54e23f3900'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:25 - WARNING - Dropping a patch because it contains a previously known reference (id='be61c758-35d9-4417-82f7-fe1a1cec40c8'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:26 - WARNING - Dropping a patch because it contains a previously known reference (id='3bbd9f2a-21dc-422b-b9b7-1fd0f9842824'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:26 - WARNING - Dropping a patch because it contains a previously known reference (id='5d68630c-6341-4801-8884-d1bf29bfb3b8'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:26 - WARNING - Dropping a patch because it contains a previously known reference (id='94dbce8a-1bd0-4058-bb34-47014712ffbb'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:26 - WARNING - Dropping a patch because it contains a previously known reference (id='d67ce5e6-6bf8-4d6a-8c20-f64961dd6aa1'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:26 - WARNING - Dropping a patch because it contains a previously known reference (id='9b2311ef-4b09-45d8-9012-133bae54b2f1'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:26 - WARNING - Dropping a patch because it contains a previously known reference (id='3c7f112d-18a0-4e9c-bbb9-b40c9da4f945'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:26 - WARNING - Dropping a patch because it contains a previously known reference (id='92baa7ba-daf0-4577-84af-ff773e091012'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:26 - WARNING - Dropping a patch because it contains a previously known reference (id='201eb4d1-2ca2-45b2-8c4e-e3951f5fd577'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:27 - WARNING - Dropping a patch because it contains a previously known reference (id='db699c3f-6d70-43e9-87e8-4eb3917bd280'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:27 - WARNING - Dropping a patch because it contains a previously known reference (id='184798cf-ac12-441d-a258-6a5c983fb431'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:27 - WARNING - Dropping a patch because it contains a previously known reference (id='fa1b7f1f-e3c4-495f-8fb8-cef8555c92e4'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:27 - WARNING - Dropping a patch because it contains a previously known reference (id='76a57c8c-23c6-45df-a191-326f75d7e81c'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:31 - WARNING - Dropping a patch because it contains a previously known reference (id='6e2210c1-05b1-4ec8-aba0-b1d14118fa16'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:31 - WARNING - Dropping a patch because it contains a previously known reference (id='9dd1faf8-9c75-4b91-8d9e-d80a2f800615'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:32 - WARNING - Dropping a patch because it contains a previously known reference (id='2deb2468-2204-4e06-8940-ab024653eb7f'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:32 - WARNING - Dropping a patch because it contains a previously known reference (id='44e7710e-119c-4ca8-891f-608e21f0305f'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:32 - WARNING - Dropping a patch because it contains a previously known reference (id='2407b59f-aa6e-4702-a6ee-29e3c72e0005'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:32 - WARNING - Dropping a patch because it contains a previously known reference (id='e7b14497-5cb3-4e40-b076-5803bb3150a5'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:33 - WARNING - Dropping a patch because it contains a previously known reference (id='d02857ba-bbc8-4e6b-bb6c-eaf9be3db811'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:33 - WARNING - Dropping a patch because it contains a previously known reference (id='01e59fb4-6a31-47c2-bfdf-71ec9a7a714f'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:33 - WARNING - Dropping a patch because it contains a previously known reference (id='e98200a6-e117-40ca-b893-c5c98b00e402'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:33 - WARNING - Dropping a patch because it contains a previously known reference (id='a6bfa0e9-2ab4-4a06-97ea-ac1d22678aad'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:33 - WARNING - Dropping a patch because it contains a previously known reference (id='dd5eeca5-9a3f-42ec-aee7-518ce97635ad'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# 2025-05-03 08:07:33 - WARNING - Dropping a patch because it contains a previously known reference (id